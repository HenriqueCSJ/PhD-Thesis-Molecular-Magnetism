# %%
import matplotlib.image as mpimg #pour les imagesfrom matplotlib.patches import Polygon, Ellipse, Wedgefrom matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBboxfig = figure()fig.set_size_inches(10,12)ax1 = fig.add_subplot(211)ax2 = fig.add_subplot(212)r1 = Ellipse((-0.1,0.5),0.8,0.4,facecolor="#C0C0C0")ax1.add_patch(r1)r2 = Ellipse((1.1,0.5),0.8,0.4,facecolor="#C0C0C0")ax1.add_patch(r2)r4 = Wedge((0.5,0.5),0.1,0+45,180+45,color="red", alpha=0.7)r5 = Wedge((0.5,0.5),0.1,180+45,360+45,color="blue", alpha=0.5)ax1.add_patch(r4)ax1.add_patch(r5)ax1.set_aspect("equal")ax1.text(0.4,0.6,"$S_{N+1}$",fontsize=21,va="bottom",color="red",alpha=0.7)ax1.text(0.6,0.4,"$S_{N}$",fontsize=21,va="bottom",color="blue",alpha=0.5)arrowpropsleft=dict(arrowstyle='<-',connectionstyle="arc3,rad=0.3",linewidth=5,color="red",alpha=0.7)ax1.annotate("",(0.3,0.55),(0.4, 0.55),ha="center",va="center",arrowprops=arrowpropsleft)arrowpropsleft=dict(arrowstyle='<-',connectionstyle="arc3,rad=0.3",linewidth=5,color="blue",alpha=0.5)ax1.annotate("",(0.6,0.55),(0.7, 0.55),ha="center",va="center",arrowprops=arrowpropsleft)ax1.set_xlim(0,1)ax1.set_ylim(0.2,0.8)r1 = Ellipse((-0.1,0.5),0.8,0.4,facecolor="#C0C0C0")ax2.add_patch(r1)r2 = Ellipse((1.1,0.5),0.8,0.4,facecolor="#C0C0C0")ax2.add_patch(r2)r4 = Wedge((0.5,0.45),0.1,0+45,180+45,color="red", alpha=0.7)r5 = Wedge((0.5,0.45),0.1,180+45,360+45,color="blue", alpha=0.5)r6 = Wedge((0.5,0.75),0.1,0,360,color="green", alpha=0.1)ax2.add_patch(r4)ax2.add_patch(r5)ax2.add_patch(r6)ax2.set_aspect("equal")ax2.text(0.4,0.55,"$N+1$",fontsize=21,va="bottom",color="red",alpha=0.7)ax2.text(0.6,0.35,"$N$",fontsize=21,va="bottom",color="blue",alpha=0.5)arrowpropsleft=dict(arrowstyle='<-',connectionstyle="arc3,rad=0.3",linewidth=5,color="red",alpha=0.7)ax2.annotate("",(0.31,0.5),(0.4, 0.5),ha="center",va="center",arrowprops=arrowpropsleft)arrowpropsleft=dict(arrowstyle='<-',connectionstyle="arc3,rad=0.3",linewidth=5,color="blue",alpha=0.5)ax2.annotate("",(0.6,0.5),(0.7, 0.5),ha="center",va="center",arrowprops=arrowpropsleft)arrowpropsleft=dict(linewidth=6,color="green",frac=0.3,headwidth=28)ax2.annotate("",(0.55, 0.8),(0.45,0.7),ha="center",va="center",arrowprops=arrowpropsleft)arrowpropsleft=dict(arrowstyle='<->',connectionstyle="arc3,rad=-0.3",linewidth=5,color="green",alpha=0.5)ax2.annotate("",(0.55,0.55),(0.55, 0.75),ha="center",va="center",arrowprops=arrowpropsleft)ax2.set_xlim(0,1)ax2.set_ylim(0.3,0.9)ax1.text(0.05,0.9,'a',fontsize=21,fontweight="bold",transform = ax1.transAxes)ax2.text(0.05,0.9,'b',fontsize=21,fontweight="bold",transform = ax2.transAxes)ax1.set_axis_off()ax2.set_axis_off()fig.subplots_adjust(hspace=0,left=0, right=1,bottom=0, top=1)fig.savefig("/home/hukadan/These/Manuscript/Resultats/DirVsInd/DirVsInd.pdf")

# %%
ax1.text?
