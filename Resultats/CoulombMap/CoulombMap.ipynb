# %%
import ossys.path.append("/home/hukadan/These")from setproc.cycle_process.classes.cycle_process import CycleProcessfrom setproc.map.classes.map import Mapos.chdir("/media/Iomega_HDD/Measures/Tb2C/sample3/7R/J9/Map_toward_kondo_2/")Map1 = Map("MapBVdsVg_Vds.json","V_g","V_ds")Map1.MapPhase()
