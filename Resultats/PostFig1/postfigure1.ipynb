# %%
#from matplotlib.pyplot import figure

fig = figure(figsize=(12,10))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)

ax1.plot([0,3.4],[0.085,-0.085],'b',lw=3)
ax1.plot([3.4,6.8],[-0.085,0.085],'r',lw=3)
ax1.plot([6.8,10.2],[0.085,-0.085],'black',lw=3)
ax1.plot([10.2,13.6],[-0.085,0.085],'black',lw=3)
ax1.plot([13.6,17],[0.085,-0.085],'black',lw=3)
ax1.plot([17,20.4],[-0.085,0.085],'black',lw=3)
ax1.set_xlim(0,20)
ax1.set_ylim(-0.1,0.1)
ax1.yaxis.set_ticks([-0.085,0,0.085])
ax1.yaxis.set_ticklabels([-85,0,85])
ax1.set_xlabel(r"$t$ (s)")
ax1.set_ylabel(r"$B$ (mT)")


ax2.plot([0,3.4],[0.085,-0.085],'b',lw=3)
ax2.plot([3.4,8.4],[-0.085,-0.085],'g',lw=3)
ax2.plot([8.4,11.8],[-0.085,0.085],'r',lw=3)
ax2.plot([11.8,14.2],[0.085,-0.085],'black',lw=3)
ax2.plot([14.2,19.2],[-0.085,-0.085],'g',lw=3)
ax2.plot([19.2,22.6],[-0.085,0.085],'black',lw=3)
ax2.set_xlim(0,20)
ax2.set_ylim(-0.1,0.1)
ax2.yaxis.set_ticks([-0.085,0,0.085])
ax2.yaxis.set_ticklabels([-85,0,85])
ax2.set_xlabel(r"$t$ (s)")
ax2.set_ylabel(r"$B$ (mT)")



ax3.plot([0,3.4],[0.085,-0.085],'b',lw=3)
ax3.plot([3.4,6.8],[-0.085,0.085],'black',lw=3)
ax3.plot([6.8,10.2],[0.085,-0.085],'black',lw=3)
ax3.plot([10.2,13.6],[-0.085,0.085],'r',lw=3)
ax3.plot([13.6,17],[0.085,-0.085],'black',lw=3)
ax3.plot([17,20.4],[-0.085,0.085],'black',lw=3)
ax3.set_xlim(0,20)
ax3.set_ylim(-0.1,0.1)
ax3.yaxis.set_ticks([-0.085,0,0.085])
ax3.yaxis.set_ticklabels([-85,0,85])
ax3.set_xlabel(r"$t$ (s)")
ax3.set_ylabel(r"$B$ (mT)")



ax4.plot([0.019,0.019],[0.085,-0.085],'b--',lw=3)

ax4.plot([0.085,-0.085],[0.019,0.019],'r--',lw=3)

ax4.set_xlim(-0.05,0.05)
ax4.set_ylim(-0.05,0.05)
ax4.xaxis.set_ticks([-0.04,-0.02,0,0.02,0.04])
ax4.xaxis.set_ticklabels([-40,-20,0,20,40])
ax4.yaxis.set_ticks([-0.04,-0.02,0,0.02,0.04])
ax4.yaxis.set_ticklabels([-40,-20,0,20,40])
ax4.set_xlabel(r"$B$ (mT)")
ax4.set_ylabel(r"$B$ (mT)")

ax1.text(-0.1, 0.95,'a', horizontalalignment='center',fontsize=22, fontweight='bold', verticalalignment='center', transform = ax1.transAxes)
ax2.text(-0.1, 0.95,'b', horizontalalignment='center',fontsize=22, fontweight='bold', verticalalignment='center', transform = ax2.transAxes)
ax3.text(-0.1, 0.95,'c', horizontalalignment='center',fontsize=22, fontweight='bold', verticalalignment='center', transform = ax3.transAxes)
ax4.text(-0.1, 0.95,'d', horizontalalignment='center',fontsize=22, fontweight='bold', verticalalignment='center', transform = ax4.transAxes)

fig.subplots_adjust(right=0.98, left =0.08)

fig.savefig("/home/hukadan/PhD-Thesis-Molecular-Magnetism/Resultats/PostFig1/postfig1.pdf",dpi=300)

# %%
170/50.
# Out:
# 3.4
