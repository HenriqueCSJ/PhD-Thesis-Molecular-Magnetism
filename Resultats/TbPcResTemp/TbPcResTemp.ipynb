# %%
import osimport matplotlib.image as mpimg #pour les imagesos.chdir("/home/hukadan/These/Manuscript/Resultats/TbPcResTemp/")

# %%
fig = figure()fig.set_size_inches(10,5)ax1 = fig.add_subplot(111)#fig aTb = mpimg.imread("/home/hukadan/These/Manuscript/Resultats/TbPcResTemp/image.png")Tb = Tb.tolist()Tb.reverse()ax1.imshow(Tb, extent = [0,3000,0,2])#ax1.set_ylim(-1.1,1.1)ax1.set_xlabel(r"$m/Z$ (Th)")ax1.set_ylabel(r"$a.u$")ax1.xaxis.set_ticks([0,1000,2000,3000])ax1.xaxis.set_ticklabels([0,1000,2000,3000])ax1.yaxis.set_ticks([])#aspectxmin= ax1.get_xlim()ymin= ax1.get_ylim()a1 = 1.0 * abs((xmin[0]-xmin[1])/(ymin[0]-ymin[1]))ax1.set_aspect(a1*0.4)fig.subplots_adjust(left=0.05,right=0.95)fig.savefig("/home/hukadan/These/Manuscript/Resultats/TbPcResTemp/TbPcResTemp.pdf",dpi=600)
