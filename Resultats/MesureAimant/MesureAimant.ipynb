# %%
import osimport matplotlib.image as mpimg #pour les imagesos.chdir("/home/hukadan/These/Manuscript/Resultats/MesureAimant/")

# %%
Hist = np.loadtxt("hyst.txt")

# %%
X = []Y = []for x in Hist :    X.append(x[0])    Y.append(x[1])

# %%
plot(X,Y)ax=gca()ax.set_xlim(-1,1)ax.set_ylim(-1.1,1.1)
# Out:
# (-1.1, 1.1)

# %%
fig = figure()fig.set_size_inches(12,5.5)ax1 = fig.add_subplot(121)ax2 = fig.add_subplot(122)#fig aTb = mpimg.imread("/home/hukadan/These/Manuscript/Resultats/MesureAimant/Image.png")Tb = Tb.tolist()Tb.reverse()ax1.imshow(Tb, extent = [-1.2,1.2,-1,1])ax1.set_ylim(-1.1,1.1)ax1.set_xlabel(r"$B$ (T)")ax1.set_ylabel(r"$M/M_{\rm{s}}$")ax1.xaxis.set_ticks([-1,0,1])ax1.yaxis.set_ticks([-1,0,1])#fig bTbZ = mpimg.imread("/home/hukadan/These/Manuscript/Resultats/MesureAimant/ImageZoom.png")TbZ = TbZ.tolist()TbZ.reverse()ax2.imshow(TbZ, extent = [-0.06,0.06,-1,1])ax2.set_ylim(-1.1,1.1)ax2.set_xlabel(r"$B$ (T)")ax2.set_ylabel(r"$M/M_{\rm{s}}$")ax2.xaxis.set_ticks([-0.05,0,0.05])ax2.yaxis.set_ticks([-1,0,1])#aspectxmin= ax1.get_xlim()ymin= ax1.get_ylim()a1 = 1.0 * abs((xmin[0]-xmin[1])/(ymin[0]-ymin[1]))xmin= ax2.get_xlim()ymin= ax2.get_ylim()a2 = 1.0 * abs((xmin[0]-xmin[1])/(ymin[0]-ymin[1]))ax1.set_aspect(a1*0.8,)ax2.set_aspect(a2*0.8,)fig.subplots_adjust(left=0.05,right=0.98,wspace=0.15,hspace=0.30, top = 0.95, bottom = 0.08)fig.savefig("/home/hukadan/These/Manuscript/Resultats/MesureAimant/MesureAimant.pdf",dpi=600)
