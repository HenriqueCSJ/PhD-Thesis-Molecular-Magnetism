# %%
import matplotlib.image as mpimg #pour les imagesfrom matplotlib.patches import Polygon, Circlefrom matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox

# %%
Mesure = mpimg.imread("/home/hukadan/These/Manuscript/Fabrication/ZoomFinal/image.png")Mesure = Mesure.tolist()Mesure.reverse()fig = figure(figsize=(12,12))ax1 = fig.add_subplot(111)im = ax1.imshow(Mesure)#ax1.set_xlim(50,950)ax1.set_axis_off()fig.subplots_adjust(top=1, bottom=0, left=0, right=1)fig.savefig("/home/hukadan/These/Manuscript/Fabrication/ZoomFinal/ZoomFinal.pdf", dpi=600)
