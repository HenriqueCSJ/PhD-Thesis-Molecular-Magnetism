# %%
import osos.chdir("/home/hukadan/These/Manuscript/Fabrication/NotreElectroMig/")

# %%
ElctroMig = np.loadtxt("donnee.txt")

# %%
X = []Y = []Z = []for x in ElctroMig :    X.append(x[0])    Y.append(x[1])    Z.append(x[2])

# %%
start = 900end = 1300plot(X[start:end],Z[start:end ])

# %%
from matplotlib.patches import Polygon, Circlefig = figure()ax1 = fig.add_subplot(121)ax2 = fig.add_subplot(122)fig.set_size_inches(12,5.5)start = 900end = 1300ax1.plot(X[:end],Z[:end ])ax2.plot(X[start:end],Z[start:end ])ax1.set_xlim(0.1,0.5)ax1.set_ylim(0,100)ax2.set_xlim(0.36,0.5)ax2.set_ylim(0,16)ax2.grid(axis="y")ax1.xaxis.set_ticks([0.2,0.3,0.4])ax2.xaxis.set_ticks([0.38,0.4,0.42,0.44,0.46,0.48])ax1.yaxis.set_ticks([20,40,60,80])ax2.yaxis.set_ticks([1,3,5,7,9,11,13,15])ax2.yaxis.set_ticklabels([1,3,5,7,9,11,13,])r1 = Polygon([[0.36,0],[0.36,16],[0.5,16],[0.5,0]], facecolor="#C0C0C0", edgecolor="black")ax1.add_patch(r1)#aspectxmin= ax1.get_xlim()ymin= ax1.get_ylim()a1 = 1.0 * abs((xmin[0]-xmin[1])/(ymin[0]-ymin[1]))xmin= ax2.get_xlim()ymin= ax2.get_ylim()a2 = 1.0 * abs((xmin[0]-xmin[1])/(ymin[0]-ymin[1]))ax1.set_aspect(a1*0.9,)ax2.set_aspect(a2*0.9,)ax1.set_xlabel(r"$V$ (V)")ax1.set_ylabel(r"$G$ ($G_0$)")ax2.set_xlabel(r"$V$ (V)")ax2.set_ylabel(r"$G$ ($G_0$)")ax1.text(-0.05, 0.95,'a', fontsize=20,fontweight = "bold", horizontalalignment='center', verticalalignment='center',transform = ax1.transAxes)ax2.text(-0.05, 0.95,'b', fontsize=20,fontweight = "bold", horizontalalignment='center', verticalalignment='center',transform = ax2.transAxes)#layoutfig.subplots_adjust(left=0.09,right=0.97,wspace=0.25)fig.savefig("/home/hukadan/These/Manuscript/Fabrication/NotreElectroMig/NotreElectroMig.pdf")

# %%
ax2.grid?
