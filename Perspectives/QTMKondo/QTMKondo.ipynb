# %%
sys.path.append("/home/hukadan/These/")from setproc.cycle_process.classes.cycle_process import CycleProcessfrom setproc.common.functions.local_extrema import local_extremaimport osos.chdir("/media/Iomega_HDD/Measures/Tb2C/sample3/7R/J9/kondoVg1/Cycle1/")Cyc37 = CycleProcess("G_B_trace.json","G_B_retrace.json",[0],"Json");Cyc37.GetStat(200,4)
# Out:
# Loading  0G_B_trace.json  file. Please wait..	The maximum difference is
#  652  points with the sweep  819Merging....Loading
#  0G_B_retrace.json  file. Please wait..	Perfect matching
# Merging....Finale sanity check once merged
# trace....	Perfect matching
# retrace...	Perfect matching
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /media/Iomega_HDD/Measures/Tb2C/sample3/7R/J9/kondoVg1/Cycle1/<ipython-input-1-e48a11c7d7f3> in <module>()
#       6 os.chdir("/media/Iomega_HDD/Measures/Tb2C/sample3/7R/J9/kondoVg1/Cycle1/")
#       7 Cyc37 = CycleProcess("G_B_trace.json","G_B_retrace.json",[0],"Json");
# ----> 8 Cyc37.GetStat(200,4)
#
# /home/hukadan/These/setproc/cycle_process/classes/cycle_process.pyc in GetStat(self, i_start, w, power, sw, mode, seuil1, seuil2, span)
#     139
#     140             #RETRACE STAT
#
# ...

# %%
Cyc37.GetValueStat()Cyc37.SetPlotCalibration([10**-28.8,10**-28,[-0.4,0.4],-0.019])Cyc37.PlotHysteresis(-0.4,0.4,bins=1000,offset=[0.01,-0.006]);ax=gca()ax.set_xlim(-0.35,0.35)
# Out:
# (-0.35, 0.35)

# %%
Cyc37["metadata"]
# Out:
# {u'AR': {u'B_end': 0.4,  u'B_speed': 0.025,  u'B_start': -0.4,  u'angle': 2.844886680750757,  u'nbr_AR': 1000,  u'waiting_time': 0}, u'Bt': {u'Bt_end': -0.7, u'Bt_start': -0.701, u'Bt_step': 0.0001}, u'creator': u'NanoQt 0.4.1+svn', u'filetype': u'NanoQt JSON data file', u'filter': {u'sigma': 4, u'w': 17}, u'inputs': {u'8': {u'name': u'Id',   u'scale': -2.857142857142857e-05,   u'unit': u'A'}}, u'lockin': {u'ampl_lock': 0.00035, u'freq_lock': 61.33, u'tau_lock': 0.2}, u'outputs': {u'1': {u'name': u'Vg', u'scale': 5, u'unit': u'V'},  u'2': {u'name': u'Hx', u'scale': 5.5, u'unit': u'T'},  u'3': {u'name': u'Hy', u'scale': 2, u'unit': u'T'},  u'8': {u'name': u'Vds', u'scale': 0.01, u'unit': u'V'}}, u'pol': {u'IV_gain': -1000000000,  u'Vds_gain': 0.001,  u'Vds_set': 5e-05,  u'Vg_gain': 0.5,  u'Vg_set': -0.4}, u'sample_rate': 35, u'saving': {u'comments': u'44 degree..  position 2 .. 100mK, second degeneracy point ',  u'filename': u'G_B',  u'folder': u'/home/dilu-d103/Data/Tb2C/Sample3/7R/J
# ...
