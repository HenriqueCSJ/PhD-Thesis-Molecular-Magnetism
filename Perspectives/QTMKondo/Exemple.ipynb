# %%
import osimport matplotlib.image as mpimg #pour les imagesos.chdir("/home/hukadan/These/Manuscript/Resultats/MesureAimant/")

# %%
Hist = np.loadtxt("hyst.txt")

# %%
X = []Y = []for x in Hist :    X.append(x[0])    Y.append(x[1])

# %%
plot(X,Y)ax=gca()ax.set_xlim(-0.075,0.075)ax.set_ylim(-1.1,1.1)
# Out:
# (-1.1, 1.1)

# %%
sys.path.append("/home/hukadan/These/")from setproc.cycle_process.classes.cycle_process import CycleProcessfrom setproc.common.functions.local_extrema import local_extremaimport os# <codecell>os.chdir("/media/Iomega_HDD/Measures/Tb2C/sample3/6R/J9/Cycle/Cycle6/");Cyc37 = CycleProcess("G_B_trace.json","G_B_retrace.json",[1],"Json");Cyc37.GetStat(200,4)
# Out:
# Loading  1G_B_trace.json  file. Please wait..	Perfect matching
# Merging....Loading
#  1G_B_retrace.json  file. Please wait..	Perfect matching
# Merging....Finale sanity check once merged
# trace....	Perfect matching
# retrace...	Perfect matching
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /media/Iomega_HDD/Measures/Tb2C/sample3/6R/J9/Cycle/Cycle6/<ipython-input-5-12b9d94b0287> in <module>()
#       8 os.chdir("/media/Iomega_HDD/Measures/Tb2C/sample3/6R/J9/Cycle/Cycle6/");
#       9 Cyc37 = CycleProcess("G_B_trace.json","G_B_retrace.json",[1],"Json");
# ---> 10 Cyc37.GetStat(200,4)
#
# /home/hukadan/These/setproc/cycle_process/classes/cycle_process.pyc in GetStat(self, i_start, w, power, sw, mode, seuil1, seuil2, span)
#     126                 print(str(int(100 * i/sweep_number)) + "%")
#     127             #TRACE STAT
#
# ...

# %%
os.chdir("/media/Iomega_HDD/Measures/Tb2C/sample3/6R/J9/Cycle/Cycle38/");Cyc38 = CycleProcess("G_B_trace.json","G_B_retrace.json",[0],"Json");Cyc38.GetStat(200,4)
# Out:
# Loading  0G_B_trace.json  file. Please wait..	The maximum difference is
#  7148  points with the sweep  787Merging....Loading
#  0G_B_retrace.json  file. Please wait..	Perfect matching
# Merging....Finale sanity check once merged
# trace....	Perfect matching
# retrace...	Perfect matching
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /media/Iomega_HDD/Measures/Tb2C/sample3/6R/J9/Cycle/Cycle38/<ipython-input-7-99300c3b4b55> in <module>()
#       1 os.chdir("/media/Iomega_HDD/Measures/Tb2C/sample3/6R/J9/Cycle/Cycle38/");
#       2 Cyc38 = CycleProcess("G_B_trace.json","G_B_retrace.json",[0],"Json");
# ----> 3 Cyc38.GetStat(200,4)
#
# /home/hukadan/These/setproc/cycle_process/classes/cycle_process.pyc in GetStat(self, i_start, w, power, sw, mode, seuil1, seuil2, span)
#     139
#     140             #RETRACE STAT
#
# ...

# %%
Cyc37.GetValueStat()Cyc37.SetPlotCalibration([10**-32.5,10**-27,[-0.4,0.4],-0.019])Cyc38.GetValueStat()Cyc38.SetPlotCalibration([10**-32.5,10**-27,[-0.4,0.4],-0.019])

# %%
Cyc37.PlotHysteresis(-0.4,0.4,bins=1000,offset=[0.01,-0.006]);ax=gca()#ax.set_xlim(-0.06,0.06)ax.set_ylim(-1.1,1.1)ax.grid()Cyc38.PlotHysteresis(-0.4,0.4,bins=1000,offset=[0.01,-0.006]);ax=gca()#ax.set_xlim(-0.06,0.06)ax.set_ylim(-1.1,1.1)ax.grid()

# %%
Cyc37["metadata"]

# %%
import ossys.path.append("/home/hukadan/These/")from setproc.cycle_process.classes.cycle_process import CycleProcessfrom setproc.common.functions.local_extrema import local_extremaos.chdir("/media/Iomega_HDD/Measures/Tb2C/sample3/6R/J9/Cycle/Cycle6/");#Cyc6 = CycleProcess("G_B_trace.json","G_B_retrace.json",[1],"Json");#Cyc6.GetStat(200,4)#Cyc6.GetValueStat()Cyc6.SetPlotCalibration([10**-32.5,10**-27,[-0.4,0.4],-0.019])T, Mt, R, Mr = Cyc6.PlotHysteresis(-0.4,0.4,bins=2000,offset=[0.01,-0.006]);    os.chdir("/media/Iomega_HDD/Measures/Tb2C/sample3/6R/J9/Cycle/Cycle37/");#Cyc37 = CycleProcess("G_B_trace.json","G_B_retrace.json",[0],"Json");#Cyc37.GetStat(200,4)#Cyc37.GetValueStat()Cyc37.SetPlotCalibration([10**-32.5,10**-27,[-0.4,0.4],-0.019])T2, Mt2, R2, Mr2 = Cyc37.PlotHysteresis(-0.4,0.4,bins=2000,offset=[0.01,-0.006]);        fig = figure()fig.set_size_inches(12,5.5)ax1 = fig.add_subplot(121)ax2 = fig.add_subplot(122)#fig aax1.plot(T,Mt,'b')ax1.plot(R,Mr,'b')ax1.set_xlim(-0.39,0.39)ax1.set_ylim(-1.1,1.1)#fig bax2.plot(T2,Mt2,'b')ax2.plot(R2,Mr2,'b')ax2.set_xlim(-0.39,0.39)ax2.set_ylim(-1.1,1.1)#aspectxmin= ax1.get_xlim()ymin= ax1.get_ylim()a1 = 1.0 * abs((xmin[0]-xmin[1])/(ymin[0]-ymin[1]))xmin= ax2.get_xlim()ymin= ax2.get_ylim()a2 = 1.0 * abs((xmin[0]-xmin[1])/(ymin[0]-ymin[1]))ax1.set_aspect(a1*0.8,)ax2.set_aspect(a2*0.8,)ax1.grid()ax2.grid()ax1.set_xlabel("$B$ (T)")ax2.set_xlabel("$B$ (T)")ax1.set_ylabel(r"$M/M_s$")#ax2.set_ylabel(r"$M/M_s$")ax2.yaxis.set_ticklabels([])ax1.text(0.05, 0.95,'a',color="black", fontsize=20, fontweight="bold", horizontalalignment='center', verticalalignment='center', transform = ax1.transAxes)ax2.text(0.05, 0.95,'b',color="black", fontsize=20, fontweight="bold", horizontalalignment='center', verticalalignment='center', transform = ax2.transAxes)fig.subplots_adjust(wspace=0.05,hspace=0.025,bottom = 0.05,top=0.98,left=0.08)#, top = 0.95, bottom = 0.08)fig.savefig("/home/hukadan/These/Manuscript/Resultats/CompCrisMolUnique/CompCrisMolUnique.pdf",dpi=600)

# %%
ax1.text?
