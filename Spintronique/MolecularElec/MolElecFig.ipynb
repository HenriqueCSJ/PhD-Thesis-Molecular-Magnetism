# %%
import matplotlib.image as mpimg #pour les imagesfrom matplotlib.patches import Polygon, Circlefrom matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox

# %%
Mesure = mpimg.imread("/home/hukadan/These/Manuscript/Spintronique/MolecularElec/image.png")Mesure = Mesure.tolist()Mesure.reverse()fig = figure(figsize=(12,5))ax1 = fig.add_subplot(111)im = ax1.imshow(Mesure)#ax1.set_xlim(50,950)ax1.set_axis_off()ax1.text(0.025, 0.95,"a",fontsize=20,fontweight="bold",horizontalalignment='center',verticalalignment='center',transform = ax1.transAxes)ax1.text(0.48, 0.95,"b",fontsize=20,fontweight="bold",horizontalalignment='center',verticalalignment='center',transform = ax1.transAxes)fig.subplots_adjust(top=1, bottom=0, left=0, right=1)fig.savefig("/home/hukadan/These/Manuscript/Spintronique/MolecularElec/MolecularElec.pdf", dpi=600)

# %%
ax1.text?
