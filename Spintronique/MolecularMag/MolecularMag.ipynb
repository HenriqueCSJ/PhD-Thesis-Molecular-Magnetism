# %%
import matplotlib.image as mpimg #pour les imagesfrom matplotlib.patches import Polygon, Circlefrom matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox

# %%
Mesure2 = mpimg.imread("/home/hukadan/These/Manuscript/Spintronique/MolecularMag/firstBerry.png")Mesure2 = Mesure2.tolist()Mesure2.reverse()Mesure1 = mpimg.imread("/home/hukadan/These/Manuscript/Spintronique/MolecularMag/firstQTM.png")Mesure1 = Mesure1.tolist()Mesure1.reverse()fig = figure(figsize=(12,4.5))ax1 = fig.add_subplot(121)ax2 = fig.add_subplot(122)im1 = ax1.imshow(Mesure1)im2 = ax2.imshow(Mesure2)ax1.set_axis_off()ax2.set_axis_off()ax1.text(0.05, 0.95,"a",fontsize=20,fontweight="bold",horizontalalignment='center',verticalalignment='center',transform = ax1.transAxes)ax2.text(0.05, 0.98,"b",fontsize=20,fontweight="bold",horizontalalignment='center',verticalalignment='center',transform = ax2.transAxes)im2 = ax2.imshow(Mesure2)fig.subplots_adjust(top=1, bottom=0, left=0, right=1,wspace=0,hspace=0)fig.savefig("/home/hukadan/These/Manuscript/Spintronique/MolecularMag/MolecularMag.pdf", dpi=600)
