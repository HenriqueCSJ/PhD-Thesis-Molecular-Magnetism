# %%
import matplotlib.image as mpimg #pour les imagesfrom matplotlib.patches import Polygon, Circlefrom matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox

# %%
fig = figure()fig.set_size_inches(12,5)ax1 = fig.add_subplot(121)ax2 = fig.add_subplot(122)#panel aMesure = mpimg.imread("/home/hukadan/These/Manuscript/Spintronique/SpinValve/FertMesure.png")Mesure = Mesure.tolist()Mesure.reverse()im = ax1.imshow(Mesure)ax1.set_xlim(50,950)ax1.set_axis_off()
