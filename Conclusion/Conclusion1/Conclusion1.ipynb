# %%
import osimport matplotlib.image as mpimg #pour les imagessys.path.append("/home/hukadan/These/")from setproc.cycle_process.classes.cycle_process import CycleProcessos.chdir("/media/Iomega_HDD/Measures/Tb2C/sample3/6R/J9/Cycle/Cycle37/");#Cyc37 = CycleProcess("G_B_trace.json","G_B_retrace.json",[0],"Json");#Cyc37.GetStat(200,4)#Cyc37.GetValueStat()#Cyc37.SetPlotCalibration([10**-32.5,10**-27,[-0.4,0.4],-0.019])T2, Mt2, R2, Mr2 = Cyc37.PlotHysteresis(-0.4,0.4,bins=2000,offset=[0.01,-0.006]);        #Mesure = mpimg.imread("/home/hukadan/These/Manuscript/Conclusion/Conclusion1/Tb 02_02.png")#Mesure = Mesure.tolist()#Mesure.reverse()#la figurefig = figure()fig.set_size_inches(12,4.5)ax1 = fig.add_subplot(121)ax2 = fig.add_subplot(122)#fig aim = ax1.imshow(Mesure)ax1.set_axis_off()#fig bax2.plot(T2,Mt2,'b')ax2.plot(R2,Mr2,'b')ax2.set_xlim(-0.39,0.39)ax2.set_ylim(-1.1,1.1)ax2.set_xlabel("$B$ (T)")ax2.set_ylabel(r"$M/M_s$")#aspectxmin= ax1.get_xlim()ymin= ax1.get_ylim()a1 = 1.0 * abs((xmin[0]-xmin[1])/(ymin[0]-ymin[1]))xmin= ax2.get_xlim()ymin= ax2.get_ylim()a2 = 1.0 * abs((xmin[0]-xmin[1])/(ymin[0]-ymin[1]))#ax1.set_aspect(a1*1,)ax2.set_aspect(a2*0.8,)ax2.text(-1.35, 0.95,'a',color="black", fontsize=20, fontweight="bold", horizontalalignment='center', verticalalignment='center', transform = ax2.transAxes)ax2.text(-0.15, 0.95,'b',color="black", fontsize=20, fontweight="bold", horizontalalignment='center', verticalalignment='center', transform = ax2.transAxes)fig.subplots_adjust(wspace=0.25,hspace=0.15,bottom = 0.1,top=0.98,left=0.08, right=0.95)#, top = 0.95, bottom = 0.08)fig.savefig("/home/hukadan/These/Manuscript/Conclusion/Conclusion1/Conclusion1.pdf", dpi=600)

# %%
ax1.text?
