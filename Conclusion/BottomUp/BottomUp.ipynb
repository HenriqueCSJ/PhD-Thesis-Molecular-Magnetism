# %%
import osimport matplotlib.image as mpimg #pour les images   Mesure = mpimg.imread("/home/hukadan/These/Manuscript/Conclusion/BottomUp/battonet_or.png")Mesure = Mesure.tolist()Mesure.reverse()#la figurefig = figure()fig.set_size_inches(6,4.5)ax1 = fig.add_subplot(111)#fig aim = ax1.imshow(Mesure)ax1.set_axis_off()fig.subplots_adjust(bottom = 0.0,top=1,left=0.00, right=1)#, top = 0.95, bottom = 0.08)fig.savefig("/home/hukadan/These/Manuscript/Conclusion/BottomUp/BottomUp.pdf", dpi=600)
