# %%
fig = figure()fig.set_size_inches(6,5.5)ax1 = fig.add_subplot(111)#etat spin nucleaireax1.plot([2,3.5],[2.1,2.1],'black')ax1.plot([2,3.5],[2.6,2.6],'black')ax1.plot([2,3.5],[3.2,3.2],'black')ax1.plot([2,3.5],[4,4],'black')ax1.text(3.7, 2.1,r'$|0\rangle$', fontsize=18, horizontalalignment='center', verticalalignment='center')ax1.text(3.7, 2.6,r'$|1\rangle$', fontsize=18, horizontalalignment='center', verticalalignment='center')ax1.text(3.7, 3.2,r'$|2\rangle$', fontsize=18, horizontalalignment='center', verticalalignment='center')ax1.text(3.7, 4,r'$|3\rangle$', fontsize=18, horizontalalignment='center', verticalalignment='center')arrowpropsleft=dict(arrowstyle='->',connectionstyle="arc3,rad=-0.0",linewidth=3,color="green")ax1.annotate("",(2.75, 2.65),(2.75,2.1),ha="center",va="center",arrowprops=arrowpropsleft)arrowpropsleft=dict(arrowstyle='->',connectionstyle="arc3,rad=-0.0",linewidth=3,color="blue")ax1.annotate("",(2.75, 3.25),(2.75,2.6),ha="center",va="center",arrowprops=arrowpropsleft)ax1.plot([0,1],[0,0],'r')x = linspace(1,2,10000)ax1.plot(x,sin(x*25*pi),'green')ax1.plot([2,3],[0,0],'r')x = linspace(1,2.5,10000)ax1.plot(x+2,sin(x*20*pi),'blue')ax1.plot([4.5,6],[0,0],'r')ax1.set_ylim(-1.5,4.5)ax1.set_yticks([])ax1.set_xticks([])ax1.set_xlabel(r"$t$ (u.a)")ax1.text(0.5, 1.3,r'', fontsize=20, horizontalalignment='center', verticalalignment='center')ax1.text(1.5, 1.3,r'$\nu_1/t_1$', color="green", fontsize=20, horizontalalignment='center', verticalalignment='center')ax1.text(2.5, 1.3,r'', fontsize=20, horizontalalignment='center', verticalalignment='center')ax1.text(3.75, 1.3,r'$\nu_2/t_2$', color="blue", fontsize=20, horizontalalignment='center', verticalalignment='center')ax1.text(5.25, 1.3,'read-out', fontsize=20, fontweight='light', horizontalalignment='center', verticalalignment='center')#compute scale multiplicatorxmin= ax1.get_xlim()ymin= ax1.get_ylim()a1 = 1.0 * abs((xmin[0]-xmin[1])/(ymin[0]-ymin[1]))ax1.set_aspect(a1*0.8)fig.savefig('/home/hukadan/These/Manuscript/Conclusion/spin_nuc_man/spin_nuc_man.pdf', dpi=600)
